# %%
import numpy as nps
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#noAQM
df_IPERF_TRAFFIC_INTESITY_NOAQM_120 = pd.read_csv('../logs/noAQM/120Mbps/log_iperf-Total_duration.txt', 
                                        names='Index ID Interval sec Transfer size Bandwidth speed'.split(), 
                                        header=None, 
                                        skiprows=7,
                                        skipfooter=6,
                                        engine='python',
                                        sep="\s+")

df_IPERF_TRAFFIC_INTESITY_NOAQM_200 = pd.read_csv('../logs/noAQM/200Mbps/log_iperf-Total_duration.txt', 
                                        names='Index ID Interval sec Transfer size Bandwidth speed'.split(), 
                                        header=None, 
                                        skiprows=7,
                                        skipfooter=6,
                                        engine='python',
                                        sep="\s+")               

df_IPERF_TRAFFIC_INTESITY_NOAQM_1000 = pd.read_csv('../logs/noAQM/1Gbps/log_iperf-Total_duration.txt', 
                                        names='Index ID Interval sec Transfer size Bandwidth speed'.split(), 
                                        header=None, 
                                        skiprows=7,
                                        skipfooter=6,
                                        engine='python',
                                        sep="\s+")


#iRED
df_IPERF_TRAFFIC_INTESITY_iRED_120 = pd.read_csv('../logs/iRED/120Mbps/log_iperf-Total_duration.txt', 
                                        names='Index ID Interval sec Transfer size Bandwidth speed'.split(), 
                                        header=None, 
                                        skiprows=7,
                                        skipfooter=6,
                                        engine='python',
                                        sep="\s+")

df_IPERF_TRAFFIC_INTESITY_iRED_200 = pd.read_csv('../logs/iRED/200Mbps/log_iperf-Total_duration.txt', 
                                        names='Index ID Interval sec Transfer size Bandwidth speed'.split(), 
                                        header=None, 
                                        skiprows=7,
                                        skipfooter=6,
                                        engine='python',
                                        sep="\s+")               

df_IPERF_TRAFFIC_INTESITY_iRED_1000 = pd.read_csv('../logs/iRED/1Gbps/log_iperf-Total_duration.txt', 
                                        names='Index ID Interval sec Transfer size Bandwidth speed'.split(), 
                                        header=None, 
                                        skiprows=7,
                                        skipfooter=6,
                                        engine='python',
                                        sep="\s+")             


#iRED_delay
df_IPERF_TRAFFIC_INTESITY_iRED_delay_120 = pd.read_csv('../logs/iRED_delay/120Mbps/log_iperf-Total_duration.txt', 
                                        names='Index ID Interval sec Transfer size Bandwidth speed'.split(), 
                                        header=None, 
                                        skiprows=7,
                                        skipfooter=6,
                                        engine='python',
                                        sep="\s+")

df_IPERF_TRAFFIC_INTESITY_iRED_delay_200 = pd.read_csv('../logs/iRED_delay/200Mbps/log_iperf-Total_duration.txt', 
                                        names='Index ID Interval sec Transfer size Bandwidth speed'.split(), 
                                        header=None, 
                                        skiprows=7,
                                        skipfooter=6,
                                        engine='python',
                                        sep="\s+")               

df_IPERF_TRAFFIC_INTESITY_iRED_delay_1000 = pd.read_csv('../logs/iRED_delay/1Gbps/log_iperf-Total_duration.txt', 
                                        names='Index ID Interval sec Transfer size Bandwidth speed'.split(), 
                                        header=None, 
                                        skiprows=7,
                                        skipfooter=6,
                                        engine='python',
                                        sep="\s+")             


#CoDel
df_IPERF_TRAFFIC_INTESITY_CoDel_120 = pd.read_csv('../logs/CoDel/120Mbps/log_iperf-Total_duration.txt', 
                                        names='Index ID Interval sec Transfer size Bandwidth speed'.split(), 
                                        header=None, 
                                        skiprows=7,
                                        skipfooter=6,
                                        engine='python',
                                        sep="\s+")

df_IPERF_TRAFFIC_INTESITY_CoDel_200 = pd.read_csv('../logs/CoDel/200Mbps/log_iperf-Total_duration.txt', 
                                        names='Index ID Interval sec Transfer size Bandwidth speed'.split(), 
                                        header=None, 
                                        skiprows=7,
                                        skipfooter=6,
                                        engine='python',
                                        sep="\s+")               

df_IPERF_TRAFFIC_INTESITY_CoDel_1000 = pd.read_csv('../logs/CoDel/1Gbps/log_iperf-Total_duration.txt', 
                                        names='Index ID Interval sec Transfer size Bandwidth speed'.split(), 
                                        header=None, 
                                        skiprows=7,
                                        skipfooter=6,
                                        engine='python',
                                        sep="\s+")

# %%
plt.figure(figsize=(20,10))
#plt.plot(df_IPERF_TRAFFIC_INTESITY_NOAQM_120["Bandwidth"].rolling(20).mean(), linewidth=3, label="noAQM")
plt.plot(df_IPERF_TRAFFIC_INTESITY_iRED_120["Bandwidth"].rolling(20).mean(), linewidth=3, label="iRED")
plt.plot(df_IPERF_TRAFFIC_INTESITY_CoDel_120["Bandwidth"].rolling(20).mean(), linewidth=3, label="CoDel")
plt.plot(df_IPERF_TRAFFIC_INTESITY_iRED_delay_120["Bandwidth"].rolling(20).mean(), linewidth=3, label="iRED_delay")
plt.legend(fontsize=20)
plt.axvline(x=120, color='black', linestyle='dotted')
plt.axvline(x=240, color='black', linestyle='dotted')
plt.axvline(x=360, color='black', linestyle='dotted')

# %%
plt.figure(figsize=(20,10))
#plt.plot(df_IPERF_TRAFFIC_INTESITY_NOAQM_200["Bandwidth"].rolling(20).mean(), linewidth=3, label="Throughput")
plt.plot(df_IPERF_TRAFFIC_INTESITY_iRED_200["Bandwidth"].rolling(20).mean(), linewidth=3, label="iRED")
plt.plot(df_IPERF_TRAFFIC_INTESITY_CoDel_200["Bandwidth"].rolling(20).mean(), linewidth=3, label="CoDel")
plt.plot(df_IPERF_TRAFFIC_INTESITY_iRED_delay_200["Bandwidth"].rolling(20).mean(), linewidth=3, label="iRED_delay")
plt.legend(fontsize=20)
plt.axvline(x=120, color='black', linestyle='dotted')
plt.axvline(x=240, color='black', linestyle='dotted')
plt.axvline(x=360, color='black', linestyle='dotted')

# %%
plt.figure(figsize=(20,10))
#plt.plot(df_IPERF_TRAFFIC_INTESITY_NOAQM_1000["Bandwidth"].rolling(20).mean(), linewidth=3, label="Throughput")
plt.plot(df_IPERF_TRAFFIC_INTESITY_iRED_1000["Bandwidth"].rolling(20).mean(), linewidth=3, label="iRED")
plt.plot(df_IPERF_TRAFFIC_INTESITY_CoDel_1000["Bandwidth"].rolling(20).mean(), linewidth=3, label="CoDel")
plt.plot(df_IPERF_TRAFFIC_INTESITY_iRED_delay_1000["Bandwidth"].rolling(20).mean(), linewidth=3, label="iRED_delay")
plt.legend(fontsize=20)
plt.axvline(x=120, color='black', linestyle='dotted')
plt.axvline(x=240, color='black', linestyle='dotted')
plt.axvline(x=360, color='black', linestyle='dotted')

# %%
f, ax = plt.subplots(figsize=(15, 8))

#ax = sns.kdeplot(pd.to_numeric(df_IPERF_TRAFFIC_INTESITY_NOAQM_120["Bandwidth"]),cumulative=True, linewidth=4)
ax = sns.kdeplot(pd.to_numeric(df_IPERF_TRAFFIC_INTESITY_iRED_120["Bandwidth"]),cumulative=True, linewidth=4, label="iRED")
ax = sns.kdeplot(pd.to_numeric(df_IPERF_TRAFFIC_INTESITY_iRED_delay_120["Bandwidth"]),cumulative=True, linewidth=4, label="iRED_delay")
ax = sns.kdeplot(pd.to_numeric(df_IPERF_TRAFFIC_INTESITY_CoDel_120["Bandwidth"]),cumulative=True, linewidth=4, label="CoDel")
plt.legend(fontsize=20)

# %%
f, ax = plt.subplots(figsize=(15, 8))

#ax = sns.kdeplot(pd.to_numeric(df_IPERF_TRAFFIC_INTESITY_NOAQM_200["Bandwidth"]),cumulative=True, linewidth=4)
ax = sns.kdeplot(pd.to_numeric(df_IPERF_TRAFFIC_INTESITY_iRED_200["Bandwidth"]),cumulative=True, linewidth=4, label="iRED")
ax = sns.kdeplot(pd.to_numeric(df_IPERF_TRAFFIC_INTESITY_iRED_delay_200["Bandwidth"]),cumulative=True, linewidth=4, label="iRED_delay")
ax = sns.kdeplot(pd.to_numeric(df_IPERF_TRAFFIC_INTESITY_CoDel_200["Bandwidth"]),cumulative=True, linewidth=4, label="CoDel")
plt.legend(fontsize=20)

# %%
f, ax = plt.subplots(figsize=(15, 8))

#ax = sns.kdeplot(pd.to_numeric(df_IPERF_TRAFFIC_INTESITY_NOAQM_1000["Bandwidth"]),cumulative=True, linewidth=4)
ax = sns.kdeplot(pd.to_numeric(df_IPERF_TRAFFIC_INTESITY_iRED_1000["Bandwidth"]),cumulative=True, linewidth=4, label="iRED")
ax = sns.kdeplot(pd.to_numeric(df_IPERF_TRAFFIC_INTESITY_CoDel_1000["Bandwidth"]),cumulative=True, linewidth=4, label="CoDel")
ax = sns.kdeplot(pd.to_numeric(df_IPERF_TRAFFIC_INTESITY_iRED_delay_1000["Bandwidth"]),cumulative=True, linewidth=4, label="iRED_delay")
plt.legend(fontsize=20)

# %%
drop_cloned_pkts_iRED_120Mbps = 77775
drop_regular_pkts_iRED_120Mbps = 39447

drop_cloned_pkts_iRED_200Mbps = 74847
drop_regular_pkts_iRED_200Mbps = 36667

drop_cloned_pkts_iRED_1Gbps = 232559
drop_regular_pkts_iRED_1Gbps = 101438

drop_cloned_pkts_iRED_delay_120Mbps = 14824
drop_regular_pkts_iRED_delay_120Mbps = 11022

drop_cloned_pkts_iRED_delay_200Mbps = 9569
drop_regular_pkts_iRED_delay_200Mbps = 7090

drop_cloned_pkts_iRED_delay_1Gbps = 538098
drop_regular_pkts_iRED_delay_1Gbps = 238807
